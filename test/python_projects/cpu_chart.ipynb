# %%
# %load_ext autoreload
# %autoreload 2

import requests
import logging

# These two lines enable debugging at httplib level (requests->urllib3->http.client)
# You will see the REQUEST, including HEADERS and DATA, and RESPONSE with HEADERS but without DATA.
# The only thing missing will be the response.body which is not logged.
# try:
#     import http.client as http_client
# except ImportError:
#     # Python 2
#     import httplib as http_client
# http_client.HTTPConnection.debuglevel = 1


import json, time 
import whatap_api
from datetime import datetime

pcode=11
oid=554410828
#cubeType='%2Fhour'
cubeType=''

cookie='_gcl_au=1.1.867332439.1621328905; _fbp=fb.1.1621328904731.1928817789; _ga=GA1.2.73872690.1621328905; _hjid=41b92274-ed03-409a-92bf-f48240176e63; ch-veil-id=227033ad-fd7b-4466-8240-0b2c6d55b8e5; lang=ko; global.skin=wh; JSESSIONID=RXcQA2QVMsonNpvChiJLwvkeBIeIJI1szf6-aB-5; wa=qMYBot2UGvX9jMkAfilxvFqyjlXE2dJkGo5rIs81iF0UDD6V3FzKDQ==; ch-session-6280=eyJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJzZXMiLCJrZXkiOiI2MjgwLTVmNWYxMTU2MTBmYTRjOGI5OWY3IiwiaWF0IjoxNjI4NDAxNDkwLCJleHAiOjE2MzA5OTM0OTB9.7lzPGWxEasED8lYkoGaSR0Ba3QPeU784kUNDSTp9YHk'
etime = int(time.time()*1000)
stime = etime - 1000*60*60*24

params={"item":"cpu","stime":stime,"etime":etime}

r = whatap_api.query(pcode=pcode, oid=oid, cubeType= cubeType, cookie=cookie, params=params)
cpu_perf = r

clocks = [datetime.fromtimestamp(int(clock/1000)) for (clock, _) in cpu_perf['idle']]
cpuHistory = [ 100 - pct for (_, pct) in cpu_perf['idle']]
cpuPercent = dict(cpuHistory = cpuHistory)

params={"item":"memory","stime":stime,"etime":etime}

r = whatap_api.query(pcode=pcode, oid=oid, cubeType= cubeType, cookie=cookie, params=params)
mem_perf = r

memHistory = [ pct for (_, pct) in mem_perf['pused']]


import pandas as pd

yarddf = pd.DataFrame(cpuPercent, index=memHistory)

import plotly.express as px
fig = px.scatter(x=memHistory, y=cpuHistory)
fig.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ...

# %%
pcode=11
oid=554410828
cubeType='%2Fhour'


cookie='_gcl_au=1.1.867332439.1621328905; _fbp=fb.1.1621328904731.1928817789; _ga=GA1.2.73872690.1621328905; _hjid=41b92274-ed03-409a-92bf-f48240176e63; ch-veil-id=227033ad-fd7b-4466-8240-0b2c6d55b8e5; lang=ko; global.skin=wh; JSESSIONID=RXcQA2QVMsonNpvChiJLwvkeBIeIJI1szf6-aB-5; wa=qMYBot2UGvX9jMkAfilxvFqyjlXE2dJkGo5rIs81iF0UDD6V3FzKDQ==; ch-session-6280=eyJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJzZXMiLCJrZXkiOiI2MjgwLTVmNWYxMTU2MTBmYTRjOGI5OWY3IiwiaWF0IjoxNjI4NDAxNDkwLCJleHAiOjE2MzA5OTM0OTB9.7lzPGWxEasED8lYkoGaSR0Ba3QPeU784kUNDSTp9YHk'
etime = int(time.time()*1000)
stime = etime - 1000*60*60*24*7

params={"item":"cpu","stime":stime,"etime":etime}

r = whatap_api.query(pcode=pcode, oid=oid, cubeType= cubeType, cookie=cookie, params=params)
cpu_perf = r

clocks = [datetime.fromtimestamp(int(clock/1000)) for (clock, _) in cpu_perf['idle']]
cpuHistory = [ 100 - pct for (_, pct) in cpu_perf['idle']]
cpuPercent = dict(cpuHistory = cpuHistory)

params={"item":"memory","stime":stime,"etime":etime}

r = whatap_api.query(pcode=pcode, oid=oid, cubeType= cubeType, cookie=cookie, params=params)
mem_perf = r

memHistory = [ pct for (_, pct) in mem_perf['pused']]


import pandas as pd

yarddf = pd.DataFrame(cpuPercent, index=memHistory)

import plotly.express as px
fig = px.scatter(x=memHistory, y=cpuHistory)

fig.update_yaxes(range=[0,100])
fig.update_xaxes(range=[0,100])
fig.show()
# Out:
# C:\Users\namhs\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning:
#
# Unverified HTTPS request is being made to host 'self.whatap.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#
# C:\Users\namhs\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning:
#
# Unverified HTTPS request is being made to host 'self.whatap.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# ...

# %%
pcode=11
oid=554410828
cubeType='%2Fhour'


cookie='_gcl_au=1.1.867332439.1621328905; _fbp=fb.1.1621328904731.1928817789; _ga=GA1.2.73872690.1621328905; _hjid=41b92274-ed03-409a-92bf-f48240176e63; ch-veil-id=227033ad-fd7b-4466-8240-0b2c6d55b8e5; lang=ko; global.skin=wh; JSESSIONID=RXcQA2QVMsonNpvChiJLwvkeBIeIJI1szf6-aB-5; wa=qMYBot2UGvX9jMkAfilxvFqyjlXE2dJkGo5rIs81iF0UDD6V3FzKDQ==; ch-session-6280=eyJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJzZXMiLCJrZXkiOiI2MjgwLTVmNWYxMTU2MTBmYTRjOGI5OWY3IiwiaWF0IjoxNjI4NDAxNDkwLCJleHAiOjE2MzA5OTM0OTB9.7lzPGWxEasED8lYkoGaSR0Ba3QPeU784kUNDSTp9YHk'
etime = int(time.time()*1000)
stime = etime - 1000*60*60*24*7

params={"item":"cpu","stime":stime,"etime":etime}

r = whatap_api.query(pcode=pcode, oid=oid, cubeType= cubeType, cookie=cookie, params=params)
cpu_perf = r

clocks = [datetime.fromtimestamp(int(clock/1000)) for (clock, _) in cpu_perf['idle']]
cpuHistory = [ 100 - pct for (_, pct) in cpu_perf['idle']]
cpuPercent = dict(cpuHistory = cpuHistory)

params={"item":"memory","stime":stime,"etime":etime}

r = whatap_api.query(pcode=pcode, oid=oid, cubeType= cubeType, cookie=cookie, params=params)
mem_perf = r

memHistory = [ pct for (_, pct) in mem_perf['pused']]


params={"item":"networks","stime":stime,"etime":etime}

r = whatap_api.query(pcode=pcode, oid=oid, cubeType= cubeType, cookie=cookie, params=params)
network_perf = r

ens5_perf = network_perf['ens5']
items = len(ens5_perf['packetIn'])
networkHistory = []
for i in range(items):
    networkHistory.append(ens5_perf['packetIn'][i][1]+ens5_perf['packetOut'][i][1])


import pandas as pd

yarddf = pd.DataFrame(cpuPercent, index=memHistory)

import plotly.express as px
#y=cpuHistory,
fig = px.scatter_3d(x=memHistory, z=networkHistory, y=cpuHistory)

fig.update_yaxes(range=[0,100])
fig.update_xaxes(range=[0,100])
fig.show()
# Out:
# C:\Users\namhs\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning:
#
# Unverified HTTPS request is being made to host 'self.whatap.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#
# C:\Users\namhs\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning:
#
# Unverified HTTPS request is being made to host 'self.whatap.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#
# C:\Users\namhs\anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning:
#
# Unverified HTTPS request is being made to host 'self.whatap.io'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# ...
