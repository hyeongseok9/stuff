# %%
import pandas as pd
import requests

url = 'https://api.covid19api.com/summary'
r = requests.get(url)
jsonr = r.json()

# %%
print(jsonr)
# Out:
# {'ID': 'bc2ce6d3-62d3-4311-98b5-147488b59820', 'Message': '', 'Global': {'NewConfirmed': 416478, 'TotalConfirmed': 162823237, 'NewDeaths': 7548, 'TotalDeaths': 3376922, 'NewRecovered': 518516, 'TotalRecovered': 99037236, 'Date': '2021-05-17T08:56:26.124Z'}, 'Countries': [{'ID': '84207d49-268d-4440-afeb-fe87389f290e', 'Country': 'Afghanistan', 'CountryCode': 'AF', 'Slug': 'afghanistan', 'NewConfirmed': 0, 'TotalConfirmed': 63484, 'NewDeaths': 0, 'TotalDeaths': 2742, 'NewRecovered': 0, 'TotalRecovered': 54686, 'Date': '2021-05-17T08:56:26.124Z', 'Premium': {}}, {'ID': '87ea5d56-4725-48fe-970c-5b6d5196efee', 'Country': 'Albania', 'CountryCode': 'AL', 'Slug': 'albania', 'NewConfirmed': 0, 'TotalConfirmed': 132015, 'NewDeaths': 0, 'TotalDeaths': 2432, 'NewRecovered': 0, 'TotalRecovered': 124312, 'Date': '2021-05-17T08:56:26.124Z', 'Premium': {}}, {'ID': 'f85e1726-ead6-4df6-a687-44d3a6cdeeb7', 'Country': 'Algeria', 'CountryCode': 'DZ', 'Slug': 'algeria', 'NewConfirmed': 0, 'TotalConfirmed'
# ...

# %%
jsonr.keys()
# Out:
# dict_keys(['ID', 'Message', 'Global', 'Countries', 'Date'])

# %%
jsonr['Countries']
# Out:
# [{'ID': '84207d49-268d-4440-afeb-fe87389f290e',
#   'Country': 'Afghanistan',
#   'CountryCode': 'AF',
#   'Slug': 'afghanistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 63484,
#   'NewDeaths': 0,
#   'TotalDeaths': 2742,
#   'NewRecovered': 0,
#   'TotalRecovered': 54686,
#   'Date': '2021-05-17T08:56:26.124Z',
#   'Premium': {}},
#  {'ID': '87ea5d56-4725-48fe-970c-5b6d5196efee',
#   'Country': 'Albania',
#   'CountryCode': 'AL',
#   'Slug': 'albania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 132015,
#   'NewDeaths': 0,
#   'TotalDeaths': 2432,
#   'NewRecovered': 0,
#   'TotalRecovered': 124312,
#   'Date': '2021-05-17T08:56:26.124Z',
#   'Premium': {}},
#  {'ID': 'f85e1726-ead6-4df6-a687-44d3a6cdeeb7',
#   'Country': 'Algeria',
#   'CountryCode': 'DZ',
#   'Slug': 'algeria',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 125311,
#   'NewDeaths': 0,
#   'TotalDeaths': 3374,
#   'NewRecovered': 0,
#   'TotalRecovered': 87359,
#   'Date': '2021-05-17T08:56:26.124Z',
# ...

# %%
df = pd.DataFrame(jsonr['Countries'])

# %%
df
# Out:
#                                        ID                          Country  \
# 0    84207d49-268d-4440-afeb-fe87389f290e                      Afghanistan
# 1    87ea5d56-4725-48fe-970c-5b6d5196efee                          Albania
# 2    f85e1726-ead6-4df6-a687-44d3a6cdeeb7                          Algeria
# 3    74a7696b-5320-4e93-a966-0bf6ec959259                          Andorra
# 4    ae9565e0-4107-445d-ac1d-b31b9e33091b                           Angola
# ..                                    ...                              ...
# 185  ee1c554e-14bc-4cc2-b2fd-2fde61bac5ed  Venezuela (Bolivarian Republic)
# 186  4667475f-1c99-4984-ae3d-55f2ef175bb1                         Viet Nam
# 187  1b922ad9-c822-436e-bd21-d807e431b516                            Yemen
# 188  cb9b5f7b-d243-43cb-83b4-072fcb5e7911                           Zambia
# 189  34b1e607-8071-4306-af21-1e71ca5e6cac                         Zimbabwe
#
# ...
